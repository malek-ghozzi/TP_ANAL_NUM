# %%
#exercice 2 
#1)

import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %%
#2)
def dicho(a,b,f,eps):
    m=(a+b)/2
    err=abs(b-a)
    while err>eps: 
        if f(m)==0: 
            return m
    
        elif f(a)*f(m)<0: 
            b=m
        else: 
            a=m
         
        m=(a+b)/2
        err=abs(b-a)
    return m

# %%
x3=dicho(-2,-1.5,f,0.001)
print(x3)
print('f(x3)={}'.format(f(x3)))
# Out:
# -1.73193359375
# f(x3)=0.0002971846843138337

# %%
x10=dicho(-2,-1.5,f,0.001)
x20=dicho(-2,-1.5,f,0.002)
print(x10,x20)
print('f(x10)={},f(x20)={}'.format(f(x10),f(x20)))
# Out:
# -1.73193359375 -1.7314453125
# f(x10)=0.0002971846843138337,f(x20)=0.0015339357778429985

# %%
x4=dicho(-2,-1.5,f,0.0001)
print(x4)
# Out:
# -1.732025146484375

# %%
# Out:
# 16.609640474436816

# %%
#3
import numpy as np
np.floor(2.3)
np.ceil(2.3)
# Out:
# 3.0

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
dicho(a,b,f,10**(-p))
#à 10^-8
# Out:
# -1.0

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dicho(u[0],u[1],f,10**(-3)))
################################################   
print(dicho(-2,-1.5,f,10**(-3)))
print(dicho(-1.5,-0.5,f,10**(-3)))
print(dicho(1.5,2,f,10**(-3)))
# Out:
# -1.73193359375
# -1.0
# 1.73193359375
# -1.73193359375
# -1.0
# 1.73193359375

# %%
import math 
def ND(a,b,p):
    n=((math.log(b-a)+p*math.log(10))/math.log(2))+1
    return n

# %%
a=-2
b=-1.5
ND(a,b,5)
# Out:
# 16.609640474436816

# %%
dicho(-2,-1.5,f,10**(-5))
# Out:
# -1.7320518493652344

# %%
#alpha 1
dicho(-2,-1.5,f,10**(-5))
#à 10^-8
# Out:
# -1.7320518493652344

# %%
#alpha 2
dicho(-1.51,-0.5,f,10**(-5))
#à 10^-8
# Out:
# -1.0000028610229492

# %%
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %%
# EXERCICE 3:
f=lambda x:x**3+x**2-10
T=linspace(1,2)
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# ![1.JPG](attachment:1.JPG)
# ![2.JPG](attachment:2.JPG)

# %%
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x: sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,nmax):
    zero=x0
    
    for niter in nmax:
        x=zero
        zero=g(x)
        erreur=abs(zero-x)
        if erreur<eps: 
            return 
    print('pas de convergence avec le nombre d''iteration indique')

# %%
ptfixe(g3,1.5,0.0001,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-8c77f8c766e0> in <module>
# ----> 1 c=ptfixe(g3,1.5,0.0001,30)
#       2 print(c)
#
# <ipython-input-69-6614e5acd00c> in ptfixe(g, x0, eps, nmax)
#       8     zero=x0
#       9
# ---> 10     for niter in nmax:
#      11         x=zero
#      12         zero=g(x)
#
# TypeError: 'int' object is not iterable

# %%
#quelle est la fonction qui donne la convergence la plus rapide ??
#Donner le nombre d'itération pour chaque méthode convergent e

#𝑔2  donne le resultat en ? itérations
#𝑔1  donne le resultat en ?
#𝑔3  est - elle convergente?
